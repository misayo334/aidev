# %% [markdown]
# # 課題4: プロ野球選手の年俸データのクラスタリング
#
# ここでは、k-means法を利用したクラスタリングの理解を深めて頂くための課題を用意しました。Lesson6で使用したプロ野球選手の推定年俸のデータを使い、クラスタリングを行ってください。なお、クラスタリングはデータを正規化したうえで行ないます。
#
# わからない場合は、ここまでのレッスン内容や各種ライブラリの公式ドキュメントを参照しましょう。

# %% [markdown]
# ## 1. ライブラリのimport

# %%
# （変更しないでください）

# 必要なライブラリのimport
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# データの正規化
from sklearn.preprocessing import MinMaxScaler

# k-means法
from sklearn.cluster import KMeans

# シルエットプロット
from sklearn.metrics import silhouette_score, silhouette_samples

# DataFrameですべての列を表示する設定
pd.options.display.max_columns = None

# seabornによる装飾を適用する
sns.set_theme()
# Out:
# /Users/MisayoMacBookPro/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## 2. データの読み込み
#
# CSVファイル *baseball_salary.csv* を読み込み、dataset_baseに格納します。

# %%
# CSVファイルを読み込んでdataset_baseに格納する
dataset_base = pd.read_csv("./baseball_salary.csv")

# %%
# dataset_baseの最初の5行を表示
dataset_base.head()
# Out:
#   球団   推定年俸   守備  年数  年齢   身長   体重  血液型  投打     年     打率   試合  打席数   打数   安打  \
# 0  c  21000  外野手  11  29  177   90  AB型  右左  2017  0.308  143  651  556  171
# 1  c  19000  内野手   7  28  171   72   A型  右右  2017  0.271  138  629  565  153
# 2  c  14000  内野手   5  29  171   85   A型  右左  2017  0.290  143  679  565  164
# 3  c  11500  内野手   7  38  196  126   不明  右右  2017  0.265  116  405  344   91
# 4  c  11000  内野手  20  41  189  102   B型  右右  2017  0.292  100  288  243   71
#
#    本塁打  打点  盗塁  四球  死球   三振  犠打  併殺打    出塁率    長打率    OPS  RC27  XR27   球団勝率  \
# 0   23  92  13  83   4  113   2    6  0.398  0.505  0.903  7.70  7.52  0.633
# 1   14  56   8  32   1  107  30    9  0.311  0.405  0.716  4.10  4.01  0.633
# 2    8  60  35  89  15  120   6    5  0.398  0.407  0.805  6.41  6.26  0.633
# 3   27  78   0  50   8  111   0    8  0.368  0.532  0.900  6.80  6.90  0.633
# 4    9  48   2  40   1   56   0    7  0.389  0.461  0.850  6.55  6.54  0.633
#
#    プレーオフ  球団平均得点   球団打率
# 0      2    5.15  0.273
# 1      2    5.15  0.273
# 2      2    5.15  0.273
# 3      2    5.15  0.273
# 4      2    5.15  0.273

# %%
# dataset_baseから「打率、打点」列を抜き出してdatasetに格納する
dataset = dataset_base[['打率', '打点']]

# 列名を、打率は「batting」、打点は「points」にリネームする
dataset = dataset.rename(columns={'打率': 'batting', '打点': 'points'})

# datasetの先頭の5行を表示
dataset.head()
# Out:
#    batting  points
# 0    0.308      92
# 1    0.271      56
# 2    0.290      60
# 3    0.265      78
# 4    0.292      48

# %% [markdown]
# ## 3. データの正規化
#
# クラスタリングは類似度（距離）に基づいて行なわれるため、データの範囲に差がある場合は正規化を行ないます。
#
# ここでは、Lesson5のデータの前処理で紹介した *Min-max normalization* を使ってみましょう。 `sklearn.preprocessing.MinMaxScaler()` を利用します。
#
# 参考：https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html

# %%
# MinMaxScalerで正規化を実施し、その結果を変数tempに格納する

#from sklearn.preprocessing import MinMaxScaler  すでにimport済み
ms = MinMaxScaler()
ms.set_output(transform='pandas')   #出力をnumpy.ndarrayではなく、PandasのDataFrameになるよう指定する。
temp = ms.fit_transform(dataset)
temp
# Out:
#      batting    points
# 0      0.616  0.876190
# 1      0.542  0.533333
# 2      0.580  0.571429
# 3      0.530  0.742857
# 4      0.584  0.457143
# ..       ...       ...
# 236    0.342  0.009524
# 237    0.412  0.219048
# 238    0.390  0.019048
# 239    0.476  0.000000
# 240    0.308  0.000000
#
# [241 rows x 2 columns]

# %%
# 正規化後のデータの先頭の5行を表示

temp.head()
# Out:
#    batting    points
# 0    0.616  0.876190
# 1    0.542  0.533333
# 2    0.580  0.571429
# 3    0.530  0.742857
# 4    0.584  0.457143

# %%
# tempの0列目を「batting_scaled」、1列目を「points_scaled」という列名にして、datasetへ列として追加
dataset['batting_scaled'] = temp['batting']
dataset['points_scaled'] = temp['points']

# 改めてdatasetの先頭の5行を表示
dataset.head()
# Out:
#    batting  points  batting_scaled  points_scaled
# 0    0.308      92           0.616       0.876190
# 1    0.271      56           0.542       0.533333
# 2    0.290      60           0.580       0.571429
# 3    0.265      78           0.530       0.742857
# 4    0.292      48           0.584       0.457143

# %%
# 欠損値の数の確認
dataset.isnull().sum()
# Out:
# batting           0
# points            0
# batting_scaled    0
# points_scaled     0
# dtype: int64

# %% [markdown]
# ## 4. データの可視化

# %%
# 正規化後の打率と打点の散布図を描画する
dataset.plot(kind='scatter', x='batting_scaled', y='points_scaled')
# Out:
# <Axes: xlabel='batting_scaled', ylabel='points_scaled'>

# %% [markdown]
# ## 5. クラスター数の決定
#
# エルボーメソッドとシルエットプロットを使用してクラスター数を決定しましょう

# %% [markdown]
# ### クラスタリングを行なうデータの抽出

# %%
# datasetからbatting_scaledとpoints_scaledを取り出して、numpy配列に変換してXに格納する

X = np.array(dataset[['batting_scaled', 'points_scaled']])

# Xの形状を確認

print("X=", X.shape)
# Out:
# X= (241, 2)

# %% [markdown]
# ### エルボーメソッド

# %%
# 最大クラスター数を10として、クラスター数1から10までのWCSS値を算出（変更しないでください）
wcss = []
c_list = np.arange(1, 11)

# %%
# クラスタ数の算出
for c in c_list:
    # クラスタ数を c で指定
    kmeans_model = KMeans(n_clusters=c, init='k-means++', n_init=11)
    kmeans_model.fit(X)
    # inertia_プロパティに、WCSSが格納されている
    wcss.append(kmeans_model.inertia_)

# %%
# WCSSの表示（変更しないでください）
wcss
# Out:
# [19.166235457325396,
#  7.410516705251341,
#  5.19035543662267,
#  3.6886547855136653,
#  2.5958700849196967,
#  1.9263829763388607,
#  1.6628524307745547,
#  1.4269692549043373,
#  1.2310032469269645,
#  1.1052187013993318]

# %%
# エルボーメソッドのグラフの表示
sns.lineplot(x=c_list, y=wcss)
# Out:
# <Axes: >

# %% [markdown]
# ### シルエットプロット

# %%
# クラスタ数を6に指定（変更しないでください）
cluster_no = 6

# %%
# クラスタリングのモデルを作成し、学習して、クラスタ番号を取得
kmeans_model = KMeans(n_clusters=cluster_no, init='k-means++', n_init=10)
Y_pred = kmeans_model.fit_predict(X)

# %%
# シルエットスコアの平均値
s_average = silhouette_score(X, Y_pred)

# 各データのシルエットスコア
s_score = silhouette_samples(X, Y_pred, metric='euclidean')

# %%
# シルエットプロットを描画
fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
y_lower = 0

for i in range(cluster_no):
    # Aggregate the silhouette scores for samples belonging to
    # cluster i, and sort them
    ith_cluster_silhouette_values = s_score[Y_pred == i]
    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    #color = cm.nipy_spectral(float(i) / n_clusters)
    ax1.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_values)

    # Label the silhouette plots with their cluster numbers at the middle
    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for next plot
    y_lower = y_upper + 10  # 10 for the 0 samples

ax1.set_title("The silhouette plot for the various clusters.")
ax1.set_xlabel("The silhouette coefficient values")
ax1.set_ylabel("Cluster label")

# The vertical line for average silhouette score of all the values
ax1.axvline(x=s_average, color="red", linestyle="--")

ax1.set_yticks([])  # Clear the yaxis labels / ticks
ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
# Out:
# [<matplotlib.axis.XTick at 0x17e1ead50>,
#  <matplotlib.axis.XTick at 0x17e1a5850>,
#  <matplotlib.axis.XTick at 0x17fdb6f90>,
#  <matplotlib.axis.XTick at 0x17fda1990>,
#  <matplotlib.axis.XTick at 0x17fddef50>,
#  <matplotlib.axis.XTick at 0x17fd9e950>,
#  <matplotlib.axis.XTick at 0x17fddcd50>]

# %% [markdown]
# ## 6. 結果の確認
#
# 上記の結果をもとに、クラスタ数6で再度クラスタリングを実行し、分類ごとに色を分けて散布図にプロットしましょう。

# %%
# クラスタ数を6に指定（変更しないでください）
cluster_no = 6

# クラスタリングのモデルを作成し、学習して、クラスタ番号を取得
kmeans_model = KMeans(n_clusters=cluster_no, init='k-means++', n_init=10)
Y_pred = kmeans_model.fit_predict(X)

# %%
# k-means法によるクラスタリングの結果を描画

# グラフ化用DataFrameを作成して、tempに格納
temp2 = dataset[['batting', 'points', 'batting_scaled', 'points_scaled']].copy()
temp2['cluster'] = kmeans_model.labels_

# k-means法によるクラスタリングの結果を描画
ax = sns.lmplot(x='batting_scaled', y='points_scaled', data=temp2, hue='cluster', fit_reg=False)
ax.set(title='cluster')

# %%
# 各クラスタごとの平均値を算出（元のスケールの打率・打点で確認）
cluster_analysis = temp2.groupby('cluster')[['batting', 'points','batting_scaled','points_scaled']].mean()
print(cluster_analysis)
# Out:
#           batting     points  batting_scaled  points_scaled
# cluster
# 0        0.271909  51.931818        0.543818       0.494589
# 1        0.229947   6.723684        0.459895       0.064035
# 2        0.278600  85.650000        0.557200       0.815714
# 3        0.135538   2.307692        0.271077       0.021978
# 4        0.243260  25.600000        0.486520       0.243810
# 5        0.394500   6.416667        0.789000       0.061111
